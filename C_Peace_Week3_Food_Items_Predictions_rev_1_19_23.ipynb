# %% [markdown]
# <a href="https://colab.research.google.com/github/CRPeace/Dojo-food_items_assignment/blob/main/C_Peace_Week3_Food_Items_Predictions_rev_1_19_23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Food Item Predictions
# ##### Cameron Peace

# %% [markdown]
# ##### Assignment Checklist Part 3 Exploratory Visualizations

# %% [markdown]
# For Part 4, your task is to build several data visualizations to help your stakeholders better understand trends in the data. Feel free to get creative with this week - this is your chance to set your project apart from others with exceptional visualizations and analyses.
#
# Build on your previous cleaning, exploration, and analysis.
# Create a minimum of two data visualizations that help others understand trends in the data (explanatory data analysis).
# Since these graphs are for reporting purposes, make sure they look nice by including titles, legends, etc. Also, explanatory visualizations should be for a non technical audience (no boxplots, heatmaps, piecharts in general).  Should provide a recommendation.

# %% [markdown]
# ##### Data Background and Data Dictionary

# %% [markdown]
# The dataset used in this analysis was originally provided by [Analytics Vidhya](https://datahack.analyticsvidhya.com/) for use in a data analysis [practice competition](https://datahack.analyticsvidhya.com/contest/practice-problem-big-mart-sales-iii/#About).  It includes data on products from the grocery store chain [Big Mart](https://www.bigmart.ae/index.html), which has locations mostly in India and the United Arab Emirates. From [Analytics Vidhya](https://www.analyticsvidhya.com/blog/2016/02/bigmart-sales-solution-top-20/): **"The data scientists at BigMart have collected 2013 sales data for 1559 products across 10 stores in different cities."*
#
# * Variable Name: --	Description
# * Item_Identifier: --	Unique product ID
# * Item_Weight: --	Weight of product
# * Item_Fat_Content: --	Whether the product is low fat or regular
# * Item_Visibility: --	The percentage of total display area of all products in a store allocated to the particular product
# * Item_Type: --	The category to which the product belongs
# * Item_MRP: --	Maximum Retail Price (list price) of the product
# * Outlet_Identifier: --	Unique store ID
# * Outlet_Establishment_Year: --	The year in which store was established
# * Outlet_Size: --	The size of the store in terms of ground area covered
# * Outlet_Location_Type: --	The type of area in which the store is located
# * Outlet_Type: --	Whether the outlet is a grocery store or some sort of supermarket
# * Item_Outlet_Sales: --	Sales of the product in the particular store. This is the target variable to be predicted.

# %% [markdown]
# ### <font color='green'> Loading Data </font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('/content/sales_predictions.csv')

# %%
display(df.head(), round(df.describe(), 2), df.info(), df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 2                       1999      Medium               Tier 1
# 3                       1998         NaN               Tier 3
# 4                       1987        High               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
#        Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# count      7060.00          8523.00   8523.00                    8523.00
# mean         12.86             0.07    140.99                    1997.83
# std           4.64             0.05     62.28                       8.37
# min           4.56             0.00     31.29                    1985.00
# 25%           8.77             0.03     93.83                    1987.00
# 50%          12.60             0.05    143.01                    1999.00
# 75%          16.85             0.09    185.64                    2004.00
# max          21.35             0.33    266.89                    2009.00
#
#        Item_Outlet_Sales
# count            8523.00
# mean             2181.29
# std              1706.50
# min                33.29
# 25%               834.25
# 50%              1794.33
# 75%              3101.30
# max             13086.96
# None
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ### <font color='green'>Data Cleaning</font>

# %%
df.shape
# Out:
# (8523, 12)

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
print(f'There are {df.duplicated().sum()} duplicate rows in the dataset')
df.loc[df.duplicated(), :]
# Out:
# There are 0 duplicate rows in the dataset
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
# Looks like we have missing values in the "Item_Weight" and "Outlet_Size" columns
df.isna().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# taking a look at other values in the rows with missing weight in case there is a pattern.
df[df['Item_Weight'].isna()]
df[df['Item_Weight'].isna()]['Outlet_Identifier'].value_counts()
# Out:
# OUT027    935
# OUT019    528
# Name: Outlet_Identifier, dtype: int64

# %%
# looks like the missing weights are confined to only 2 stores: 'OUT027' and 'OUT019'
# would consult with subject matter expert, but seems simplest to drop those stores from the dataset since we're missing data from them
# dropping 2 out of 10 stores does take a bite out of the dataset though. We'll lose around 17 percent of the data here.
df['Outlet_Identifier'].value_counts(normalize=True)
# Out:
# OUT027    0.109703
# OUT013    0.109351
# OUT049    0.109117
# OUT046    0.109117
# OUT035    0.109117
# OUT045    0.108999
# OUT018    0.108882
# OUT017    0.108647
# OUT010    0.065118
# OUT019    0.061950
# Name: Outlet_Identifier, dtype: float64

# %%
# This filters out any stores that are not OUT027 or OUT019, since in this case all nulls are coming from these two stores
# Although it makes just as much sense to drop nulls via the "Item_Weight" column \
#     I prefer this way since it makes it clear that data from two stores are problematic and removes all values.
cleaned = df.copy()
cleaned = cleaned[~cleaned['Outlet_Identifier'].isin(['OUT027', 'OUT019'])]

# %%
# verifying that we're cleaned for "Item_Weight"
print(cleaned.shape)
print(cleaned.isna().sum())
# Out:
# (7060, 12)
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
# Now filling all nulls from "Outlet_Size" with 'missing value'
cleaned['Outlet_Size'] = cleaned['Outlet_Size'].fillna('missing value')

# %%
# Verifying that there are no more missing values in the whole dataset
cleaned.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
cleaned.columns # printing out column names to copy
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
# finding those I want to take a closer look at
my_columns = ['Item_Fat_Content',
       'Item_Type', 'Outlet_Identifier',
       'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
       'Outlet_Type']
for i in my_columns:
  print(i.upper(), '****\n', cleaned[i].value_counts(dropna=False))
  print('**************\n\n')
# Out:
# ITEM_FAT_CONTENT ****
#  Low Fat    4222
# Regular    2388
# LF          260
# reg         106
# low fat      84
# Name: Item_Fat_Content, dtype: int64
# **************
#
#
# ITEM_TYPE ****
#  Fruits and Vegetables    1019
# Snack Foods               988
# Household                 759
# Frozen Foods              718
# Dairy                     566
# Canned                    539
# Baking Goods              536
# Health and Hygiene        430
# Soft Drinks               374
# Meat                      337
# Breads                    204
# Hard Drinks               183
# Others                    137
# Starchy Foods             130
# Breakfast                  89
# Seafood                    51
# Name: Item_Type, dtype: int64
# **************
#
#
# OUTLET_IDENTIFIER ****
#  OUT013    932
# OUT049    930
# OUT046    930
# OUT035    930
# OUT045    929
# OUT018    928
# OUT017    926
# OUT010    555
# Name: Outlet_Identifier, dtype: int64
# **************
#
#
# OUTLET_ESTABLISHMENT_YEAR ****
#  1987    932
# 1999    930
# 1997    930
# 2004    930
# 2002    929
# 2009    928
# 2007    926
# 1998    555
# Name: Outlet_Establishment_Year, dtype: int64
# **************
#
#
# OUTLET_SIZE ****
#  missing value    2410
# Small            1860
# Medium           1858
# High              932
# Name: Outlet_Size, dtype: int64
# **************
#
#
# OUTLET_LOCATION_TYPE ****
#  Tier 2    2785
# Tier 3    2415
# Tier 1    1860
# Name: Outlet_Location_Type, dtype: int64
# **************
#
#
# OUTLET_TYPE ****
#  Supermarket Type1    5577
# Supermarket Type2     928
# Grocery Store         555
# Name: Outlet_Type, dtype: int64
# **************

# %%
#Fixing the "Item_Fat_Content" column with apply and a separate function
def fix_fat_label(label):
  if  label== 'low fat':
    return 'Low Fat'
  elif label == 'LF':
    return 'Low Fat'
  elif label == 'reg':
    return 'Regular'
  else:
    return label
    
cleaned.loc[:,'Item_Fat_Content'] = cleaned.loc[:,'Item_Fat_Content'].apply(fix_fat_label)

# %%
# checking things
cleaned['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    4566
# Regular    2494
# Name: Item_Fat_Content, dtype: int64

# %%
# fixing column names
cleaned = cleaned.rename(columns=lambda x: x.lower())

# %%
cleaned.describe(include='all').T
# Out:
#                             count unique                    top  freq  \
# item_identifier              7060   1555                  FDF22     8
# item_weight                7060.0    NaN                    NaN   NaN
# item_fat_content             7060      2                Low Fat  4566
# item_visibility            7060.0    NaN                    NaN   NaN
# item_type                    7060     16  Fruits and Vegetables  1019
# item_mrp                   7060.0    NaN                    NaN   NaN
# outlet_identifier            7060      8                 OUT013   932
# outlet_establishment_year  7060.0    NaN                    NaN   NaN
# outlet_size                  7060      4          missing value  2410
# outlet_location_type         7060      3                 Tier 2  2785
# outlet_type                  7060      3      Supermarket Type1  5577
# item_outlet_sales          7060.0    NaN                    NaN   NaN
#
#                                   mean          std     min       25%  \
# item_identifier                    NaN          NaN     NaN       NaN
# item_weight                  12.857645     4.643456   4.555   8.77375
# item_fat_content                   NaN          NaN     NaN       NaN
# item_visibility               0.063963     0.048625     0.0  0.026768
# item_type                          NaN          NaN     NaN       NaN
# item_mrp                    141.240683    62.411888   31.49   94.1436
# outlet_identifier                  NaN          NaN     NaN       NaN
# outlet_establishment_year  2000.490935     6.588984  1987.0    1997.0
# outlet_size                        NaN          NaN     NaN       NaN
# outlet_location_type               NaN          NaN     NaN       NaN
# outlet_type                        NaN          NaN     NaN       NaN
# item_outlet_sales          2118.626808  1533.445842   33.29  922.7988
#
#                                  50%       75%        max
# item_identifier                  NaN       NaN        NaN
# item_weight                     12.6     16.85      21.35
# item_fat_content                 NaN       NaN        NaN
# item_visibility             0.052493  0.092774    0.31109
# item_type                        NaN       NaN        NaN
# item_mrp                    142.7299   186.024   266.8884
# outlet_identifier                NaN       NaN        NaN
# outlet_establishment_year     2002.0    2007.0     2009.0
# outlet_size                      NaN       NaN        NaN
# outlet_location_type             NaN       NaN        NaN
# outlet_type                      NaN       NaN        NaN
# item_outlet_sales          1789.6704  2966.139  10256.649

# %% [markdown]
# ### <font color='green'>Exploratory Visuals</font>

# %%
cln_df = cleaned.copy()

# %%
cln_df.head()
# Out:
#   item_identifier  item_weight item_fat_content  item_visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                item_type  item_mrp outlet_identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    outlet_establishment_year    outlet_size outlet_location_type  \
# 0                       1999         Medium               Tier 1
# 1                       2009         Medium               Tier 3
# 2                       1999         Medium               Tier 1
# 3                       1998  missing value               Tier 3
# 4                       1987           High               Tier 3
#
#          outlet_type  item_outlet_sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052

# %%
cln_df.sort_values('item_outlet_sales', ascending=False).head(30)
# Out:
#      item_identifier  item_weight item_fat_content  item_visibility  \
# 4888           FDF39       14.850          Regular         0.019495
# 4289           NCM05        6.825          Low Fat         0.059847
# 4961           FDK03       12.600          Regular         0.074339
# 997            FDK28        5.695          Low Fat         0.065961
# 6409           FDA21       13.650          Low Fat         0.035931
# 8039           FDY55       16.750          Low Fat         0.081485
# 2216           FDT16        9.895          Regular         0.048761
# 2535           FDD44        8.050          Regular         0.078844
# 2293           FDR45       10.800          Low Fat         0.029002
# 4991           NCQ53       17.600          Low Fat         0.018905
# 5752           FDI15       13.800          Low Fat         0.141326
# 7256           DRJ39       20.250          Low Fat         0.036400
# 7076           FDR34       17.000          Regular         0.016056
# 1254           FDG47       12.800          Low Fat         0.069619
# 2776           FDB37       20.250          Regular         0.022936
# 3087           DRK23        8.395          Low Fat         0.071917
# 753            FDY26       20.600          Regular         0.030511
# 373            FDX09        9.000          Low Fat         0.065237
# 6993           FDT21        7.420          Low Fat         0.020507
# 304            DRE60        9.395          Low Fat         0.159658
# 5315           DRM37       15.350          Low Fat         0.096943
# 1506           FDB15       10.895          Low Fat         0.137023
# 5550           DRJ51       14.100          Low Fat         0.088492
# 2516           FDJ38        8.600          Regular         0.040206
# 8447           FDS26       20.350          Low Fat         0.089975
# 8245           FDU55       16.200          Low Fat         0.035967
# 3083           FDJ15       11.350          Regular         0.023318
# 276            FDY55       16.750          Low Fat         0.081253
# 145            FDP16       18.600          Low Fat         0.039356
# 7560           FDB56        8.750          Regular         0.074565
#
#                   item_type  item_mrp outlet_identifier  \
# 4888                  Dairy  261.2910            OUT013
# 4289     Health and Hygiene  262.5226            OUT046
# 4961                  Dairy  255.5356            OUT017
# 997            Frozen Foods  259.2646            OUT017
# 6409            Snack Foods  184.4924            OUT013
# 8039  Fruits and Vegetables  258.0988            OUT045
# 2216           Frozen Foods  260.5278            OUT045
# 2535  Fruits and Vegetables  257.0646            OUT017
# 2293            Snack Foods  238.6222            OUT045
# 4991     Health and Hygiene  234.6590            OUT046
# 5752                  Dairy  265.0884            OUT035
# 7256                  Dairy  219.3482            OUT045
# 7076            Snack Foods  228.4352            OUT017
# 1254          Starchy Foods  260.3252            OUT046
# 2776           Baking Goods  240.8538            OUT035
# 3087            Hard Drinks  254.8040            OUT013
# 753                   Dairy  211.4244            OUT046
# 373             Snack Foods  176.4370            OUT035
# 6993            Snack Foods  249.7092            OUT017
# 304             Soft Drinks  224.9720            OUT045
# 5315            Soft Drinks  196.5768            OUT017
# 1506                  Dairy  263.7568            OUT049
# 5550                  Dairy  231.1668            OUT017
# 2516                 Canned  188.7530            OUT046
# 8447                  Dairy  261.6594            OUT017
# 8245  Fruits and Vegetables  260.3278            OUT049
# 3083                  Dairy  182.4608            OUT035
# 276   Fruits and Vegetables  256.4988            OUT013
# 145            Frozen Foods  246.3802            OUT049
# 7560  Fruits and Vegetables  186.8556            OUT013
#
#       outlet_establishment_year    outlet_size outlet_location_type  \
# 4888                       1987           High               Tier 3
# 4289                       1997          Small               Tier 1
# 4961                       2007  missing value               Tier 2
# 997                        2007  missing value               Tier 2
# 6409                       1987           High               Tier 3
# 8039                       2002  missing value               Tier 2
# 2216                       2002  missing value               Tier 2
# 2535                       2007  missing value               Tier 2
# 2293                       2002  missing value               Tier 2
# 4991                       1997          Small               Tier 1
# 5752                       2004          Small               Tier 2
# 7256                       2002  missing value               Tier 2
# 7076                       2007  missing value               Tier 2
# 1254                       1997          Small               Tier 1
# 2776                       2004          Small               Tier 2
# 3087                       1987           High               Tier 3
# 753                        1997          Small               Tier 1
# 373                        2004          Small               Tier 2
# 6993                       2007  missing value               Tier 2
# 304                        2002  missing value               Tier 2
# 5315                       2007  missing value               Tier 2
# 1506                       1999         Medium               Tier 1
# 5550                       2007  missing value               Tier 2
# 2516                       1997          Small               Tier 1
# 8447                       2007  missing value               Tier 2
# 8245                       1999         Medium               Tier 1
# 3083                       2004          Small               Tier 2
# 276                        1987           High               Tier 3
# 145                        1999         Medium               Tier 1
# 7560                       1987           High               Tier 3
#
#             outlet_type  item_outlet_sales
# 4888  Supermarket Type1         10256.6490
# 4289  Supermarket Type1          9779.9362
# 4961  Supermarket Type1          9664.7528
# 997   Supermarket Type1          9275.9256
# 6409  Supermarket Type1          9069.5276
# 8039  Supermarket Type1          8994.9580
# 2216  Supermarket Type1          8851.1452
# 2535  Supermarket Type1          8760.5964
# 2293  Supermarket Type1          8604.7992
# 4991  Supermarket Type1          8508.9240
# 5752  Supermarket Type1          8479.6288
# 7256  Supermarket Type1          8323.8316
# 7076  Supermarket Type1          8245.2672
# 1254  Supermarket Type1          8132.0812
# 2776  Supermarket Type1          7931.6754
# 3087  Supermarket Type1          7843.1240
# 753   Supermarket Type1          7833.8028
# 373   Supermarket Type1          7763.2280
# 6993  Supermarket Type1          7719.2852
# 304   Supermarket Type1          7696.6480
# 5315  Supermarket Type1          7685.9952
# 1506  Supermarket Type1          7646.0472
# 5550  Supermarket Type1          7602.1044
# 2516  Supermarket Type1          7590.1200
# 8447  Supermarket Type1          7588.1226
# 8245  Supermarket Type1          7549.5062
# 3083  Supermarket Type1          7534.1928
# 276   Supermarket Type1          7452.9652
# 145   Supermarket Type1          7370.4060
# 7560  Supermarket Type1          7322.4684

# %% [markdown]
# #### **Correlation Check**

# %%
# Taking a look at correlated aspects to the data
plt.figure(figsize= (6, 4), dpi=125)
sns.heatmap(cln_df.corr(), cmap='coolwarm', annot=True);

# %% [markdown]
# <font color='blue'><b>Not a whole lot to learn from here, 'item outlet sales' is correlated with 'item mrp' (maximum retail price), which makes sense.  There are not many numeric variables in this dataset. I find it surprising that 'item_visibility' is not correlated with 'item_outlet_sales'.</font>

# %% [markdown]
# #### **Exploring Item Visibility**

# %% [markdown]
# Definition from the Data Dictionary:
# * **Item_Visibility:** -- The percentage of total display area of all products in a store allocated to the particular product
# <br> <br>
# <font color='blue'> I'm going to spend some time exploring Item Visibility, despite the fact that we've already learned it is not highly correlated with any other feature from the dataset, I'd like to see what I can glean.

# %%
# quick look at lowest and highest visibility items to look for patterns
display(cln_df.sort_values('item_visibility').head(10), cln_df.sort_values('item_visibility').tail(10))
# Out:
#      item_identifier  item_weight item_fat_content  item_visibility  \
# 3693           NCD07         9.10          Low Fat              0.0
# 2381           FDW34         9.60          Low Fat              0.0
# 5388           FDK52        18.25          Low Fat              0.0
# 2376           FDP60        17.35          Low Fat              0.0
# 7695           FDR48        11.65          Low Fat              0.0
# 651            FDY07        11.80          Low Fat              0.0
# 5399           FDU04         7.93          Low Fat              0.0
# 5369           FDN40         5.88          Low Fat              0.0
# 5400           DRL37        15.50          Low Fat              0.0
# 2347           FDD02        16.60          Low Fat              0.0
#
#                   item_type  item_mrp outlet_identifier  \
# 3693              Household  115.4518            OUT017
# 2381            Snack Foods  244.8170            OUT035
# 5388           Frozen Foods  224.1062            OUT018
# 2376           Baking Goods  101.9016            OUT013
# 7695           Baking Goods  149.8024            OUT018
# 651   Fruits and Vegetables   46.5402            OUT010
# 5399           Frozen Foods  121.8414            OUT046
# 5369           Frozen Foods  154.2998            OUT046
# 5400            Soft Drinks   41.3770            OUT017
# 2347                 Canned  118.8124            OUT046
#
#       outlet_establishment_year    outlet_size outlet_location_type  \
# 3693                       2007  missing value               Tier 2
# 2381                       2004          Small               Tier 2
# 5388                       2009         Medium               Tier 3
# 2376                       1987           High               Tier 3
# 7695                       2009         Medium               Tier 3
# 651                        1998  missing value               Tier 3
# 5399                       1997          Small               Tier 1
# 5369                       1997          Small               Tier 1
# 5400                       2007  missing value               Tier 2
# 2347                       1997          Small               Tier 1
#
#             outlet_type  item_outlet_sales
# 3693  Supermarket Type1          2390.8878
# 2381  Supermarket Type1          4374.3060
# 5388  Supermarket Type2          4965.5364
# 2376  Supermarket Type1          1821.6288
# 7695  Supermarket Type2          1821.6288
# 651       Grocery Store           229.7010
# 5399  Supermarket Type1          2802.3522
# 5369  Supermarket Type1          1999.3974
# 5400  Supermarket Type1           649.1550
# 2347  Supermarket Type1          2607.2728
#      item_identifier  item_weight item_fat_content  item_visibility  \
# 5374           FDU27        18.60          Regular         0.287017
# 4789           FDP19        11.50          Low Fat         0.290430
# 6674           FDS12         9.10          Low Fat         0.291439
# 3488           FDT34         9.30          Low Fat         0.291827
# 174            FDI32        17.70          Low Fat         0.291865
# 5287           FDO24        11.10          Low Fat         0.294949
# 6576           NCC18        19.10          Low Fat         0.296714
# 521            FDC15        18.10          Low Fat         0.297884
# 2855           NCE31         7.67          Low Fat         0.309390
# 7250           FDT24        12.35          Regular         0.311090
#
#                   item_type  item_mrp outlet_identifier  \
# 5374                   Meat   48.8376            OUT010
# 4789  Fruits and Vegetables  130.6652            OUT010
# 6674           Baking Goods  126.8362            OUT010
# 3488            Snack Foods  107.1964            OUT010
# 174   Fruits and Vegetables  115.1834            OUT010
# 5287           Baking Goods  159.0604            OUT010
# 6576              Household  171.8422            OUT010
# 521                   Dairy  156.7288            OUT010
# 2855              Household   33.2216            OUT010
# 7250           Baking Goods   79.2328            OUT010
#
#       outlet_establishment_year    outlet_size outlet_location_type  \
# 5374                       1998  missing value               Tier 3
# 4789                       1998  missing value               Tier 3
# 6674                       1998  missing value               Tier 3
# 3488                       1998  missing value               Tier 3
# 174                        1998  missing value               Tier 3
# 5287                       1998  missing value               Tier 3
# 6576                       1998  missing value               Tier 3
# 521                        1998  missing value               Tier 3
# 2855                       1998  missing value               Tier 3
# 7250                       1998  missing value               Tier 3
#
#         outlet_type  item_outlet_sales
# 5374  Grocery Store            47.9376
# 4789  Grocery Store           258.3304
# 6674  Grocery Store           125.8362
# 3488  Grocery Store           420.7856
# 174   Grocery Store           345.5502
# 5287  Grocery Store           792.3020
# 6576  Grocery Store          1034.6532
# 521   Grocery Store           314.2576
# 2855  Grocery Store           138.4864
# 7250  Grocery Store           154.4656

# %%
# creating filters for item visibility
only_visible = cln_df[cln_df['item_visibility'] != 0.00]
super_high_vis = cln_df[cln_df['item_visibility'] > .25]
high_vis = cln_df[cln_df['item_visibility'] > .15]
low_vis = only_visible[only_visible['item_visibility'] < .15] # don't want to see the items with no visiblity

# %%
# Most of the items in the stores seem to be low or no visibility, it would be interesting to see if there is a pattern
# Perhaps price drives higher visibility?  Item type?

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(8, 4.5), dpi=150)
plt.subplots_adjust(hspace=.4)
ax1.hist(only_visible['item_visibility'], bins=150);
ax1.set_title('All Visible Items')
ax1.set_ylabel('Item Count')

ax2.hist(low_vis['item_visibility'], bins=150);
ax2.set_title('Low Visibility')

ax3.hist(high_vis['item_visibility'], bins=150);
ax3.set_title('High Visibility')
ax3.set_ylabel('Item Count')

ax4.hist(super_high_vis['item_visibility'], bins=150);
ax4.set_title('Very High Visibility')
# Out:
# Text(0.5, 1.0, 'Very High Visibility')

# %% [markdown]
# <font color='blue'>The item counts distribution has a heavy right skew, which makes sense (there is only so much display surface in the store).  Each filter on visibility is serving as a sort of zoom in on each segment of the visibility distribution.  It will be interesting to explore if any of the very high visibilty products follow a trend and/or there is enough information present in the dataset on which to speculate a casual link. </font>

# %%
# looking for patterns, trends
super_high_vis
# Out:
#      item_identifier  item_weight item_fat_content  item_visibility  \
# 174            FDI32       17.700          Low Fat         0.291865
# 521            FDC15       18.100          Low Fat         0.297884
# 1311           FDV28       16.100          Regular         0.267353
# 1496           NCJ17        7.680          Low Fat         0.255348
# 1651           FDR43       18.200          Low Fat         0.270300
# 1841           NCJ18       12.350          Low Fat         0.274405
# 2855           NCE31        7.670          Low Fat         0.309390
# 3488           FDT34        9.300          Low Fat         0.291827
# 4530           FDZ16       16.850          Regular         0.267566
# 4789           FDP19       11.500          Low Fat         0.290430
# 4941           FDQ15       20.350          Regular         0.252866
# 5031           NCF42       17.350          Low Fat         0.280165
# 5287           FDO24       11.100          Low Fat         0.294949
# 5374           FDU27       18.600          Regular         0.287017
# 5734           FDY08        9.395          Regular         0.286345
# 5837           FDV04        7.825          Regular         0.251095
# 6576           NCC18       19.100          Low Fat         0.296714
# 6674           FDS12        9.100          Low Fat         0.291439
# 7005           DRE01       10.100          Low Fat         0.279784
# 7215           FDV21       11.500          Low Fat         0.286358
# 7250           FDT24       12.350          Regular         0.311090
# 7388           FDQ47        7.155          Regular         0.281510
#
#                   item_type  item_mrp outlet_identifier  \
# 174   Fruits and Vegetables  115.1834            OUT010
# 521                   Dairy  156.7288            OUT010
# 1311           Frozen Foods   34.9558            OUT010
# 1496     Health and Hygiene   84.4224            OUT010
# 1651  Fruits and Vegetables   38.3190            OUT010
# 1841              Household  117.1124            OUT010
# 2855              Household   33.2216            OUT010
# 3488            Snack Foods  107.1964            OUT010
# 4530           Frozen Foods  194.1478            OUT010
# 4789  Fruits and Vegetables  130.6652            OUT010
# 4941                   Meat   82.7276            OUT010
# 5031              Household  177.5712            OUT010
# 5287           Baking Goods  159.0604            OUT010
# 5374                   Meat   48.8376            OUT010
# 5734  Fruits and Vegetables  139.1838            OUT010
# 5837           Frozen Foods  156.6288            OUT010
# 6576              Household  171.8422            OUT010
# 6674           Baking Goods  126.8362            OUT010
# 7005            Soft Drinks  241.8512            OUT010
# 7215            Snack Foods  123.9704            OUT010
# 7250           Baking Goods   79.2328            OUT010
# 7388                 Breads   33.8874            OUT010
#
#       outlet_establishment_year    outlet_size outlet_location_type  \
# 174                        1998  missing value               Tier 3
# 521                        1998  missing value               Tier 3
# 1311                       1998  missing value               Tier 3
# 1496                       1998  missing value               Tier 3
# 1651                       1998  missing value               Tier 3
# 1841                       1998  missing value               Tier 3
# 2855                       1998  missing value               Tier 3
# 3488                       1998  missing value               Tier 3
# 4530                       1998  missing value               Tier 3
# 4789                       1998  missing value               Tier 3
# 4941                       1998  missing value               Tier 3
# 5031                       1998  missing value               Tier 3
# 5287                       1998  missing value               Tier 3
# 5374                       1998  missing value               Tier 3
# 5734                       1998  missing value               Tier 3
# 5837                       1998  missing value               Tier 3
# 6576                       1998  missing value               Tier 3
# 6674                       1998  missing value               Tier 3
# 7005                       1998  missing value               Tier 3
# 7215                       1998  missing value               Tier 3
# 7250                       1998  missing value               Tier 3
# 7388                       1998  missing value               Tier 3
#
#         outlet_type  item_outlet_sales
# 174   Grocery Store           345.5502
# 521   Grocery Store           314.2576
# 1311  Grocery Store            67.9116
# 1496  Grocery Store           170.4448
# 1651  Grocery Store           109.8570
# 1841  Grocery Store           355.5372
# 2855  Grocery Store           138.4864
# 3488  Grocery Store           420.7856
# 4530  Grocery Store          1162.4868
# 4789  Grocery Store           258.3304
# 4941  Grocery Store           162.4552
# 5031  Grocery Store           527.3136
# 5287  Grocery Store           792.3020
# 5374  Grocery Store            47.9376
# 5734  Grocery Store           280.9676
# 5837  Grocery Store           628.5152
# 6576  Grocery Store          1034.6532
# 6674  Grocery Store           125.8362
# 7005  Grocery Store           484.7024
# 7215  Grocery Store           375.5112
# 7250  Grocery Store           154.4656
# 7388  Grocery Store            35.2874

# %%
# Looking at a possible pattern in greater depth
super_high_vis['item_fat_content'].value_counts(normalize=True)
# Out:
# Low Fat    0.636364
# Regular    0.363636
# Name: item_fat_content, dtype: float64

# %% [markdown]
# <font color='blue'>Exploring a little more leads me to speculate on two potential causes for the high visibility values:
# * **The high visibility values represent erroneous values in the dataset, since all products with visibility score exceeding 0.25 are tied to a specific outlet/store (OUT010).  It does seem suspect that a full 1/4 (or greater!) of all display area within a store is dedicated to 1 product**.
# * **However, OUT010 represents the only "Grocery Store" type outlet in the dataset, so it may be that the store is physically much smaller and 1/4 of all display area would make sense, I would need to consult with a subject matter expert**.
#
# If I were to spend more time on this facet of the data, I would attempt to find correlations between visibility and other attributes.  The intial heatmap is not revealing a correlation, but there may be subsets within ranges of visibility scores that show trends. </font>

# %% [markdown]
# #### Exploring Item Types

# %%
plt.figure(figsize=(4,3), dpi=150)
sns.histplot(cln_df['item_type']);
plt.xticks(rotation=90);

# %% [markdown]
# <font color='blue'> Not a whole lot of surprises here.  Here are some observations:
# * **The "Fruits and Vegetables" count seems quite large, may reflect the regional variety of species, combined with seasonality. In other words, there may be a greater number of specific products that fit into this category**
# * **Some categories could probably be combined, it is hard to know where the dividing lines are without more information. e.g. Starchy Foods seem to have overlap with Snacks, Baking Goods, Breads, etc.**
# * **It would be interesting to see if these counts varied by specific store, perhaps revealing regional trends and preferences.**
# * **The counts may also vary based on the type of market.**
#
# It would be interesting to definitively learn where these outlets are located geographically. </font>

# %% [markdown]
# #### Exploring Outlet Types

# %% [markdown]
# <font color='blue'> In this section I will be looking at what effect Outlet Type has on the other categorical variables in the dataset

# %%
# grabbing columns to copy/paste from
cln_df.columns
# Out:
# Index(['item_identifier', 'item_weight', 'item_fat_content', 'item_visibility',
#        'item_type', 'item_mrp', 'outlet_identifier',
#        'outlet_establishment_year', 'outlet_size', 'outlet_location_type',
#        'outlet_type', 'item_outlet_sales'],
#       dtype='object')

# %%
# These are categorical variables I will compare between different outlet types.
features = ['item_fat_content',
       'item_type', 'outlet_identifier',
       'outlet_establishment_year', 'outlet_size', 'outlet_location_type']

# %%
# This code was modeled after a youtube video after searching for ways to use subplots and for loops
# https://www.youtube.com/watch?v=4DnWYK88-E4&ab_channel=SessionWithSumit
plt.figure(figsize=(26, 20), dpi = 125)
for i, v in enumerate(features, 1):
  plt.subplot(3, 2, i)
  sns.countplot(x = v, hue= 'outlet_type', data=cln_df);
  plt.xticks(rotation=45)
  plt.tight_layout()

# %% [markdown]
# <font color='blue'> I see very few avenues worth exploring here, I think the main lesson from these visualizations is how dominant the 'Supermarket Type1' Outlet Types are in this dataset.  The lack of Grocery Stores and Type2 outlets make this a difficult aspect of the data to explore. </font>

# %% [markdown]
# #### Exploring Item Outlet Sales

# %% [markdown]
# <font color='blue'> Here we will look at how various aspects of the dataset are affecting item_outlet_sales

# %%
features = ['item_type', 'outlet_identifier', 'outlet_size', 'outlet_location_type', 'outlet_type']

plt.figure(figsize=(20, 18), dpi=125)
for i, feature in enumerate(features, 1):
  plt.subplot(3, 2, i)
  sns.boxplot(y= feature, x='item_outlet_sales', data=cln_df);

# %% [markdown]
# <font color='blue'> Some of these boxplots are more useful than others.  Here are some observations:
# * **It's clear the 1 grocery store in the dataset is an outlier and is outcompeted by the supermarkets.**
# * **Seafood sales seem to be a have a high median value for sales.**
# * **Aside from the grocery store, the individuals are fairly closely matched.**
# * **Outlet size does not seem to make a difference on sales**
# * **Tier 3 outlets appear to be out competed by Tiers 1 and 2**
# * **The outlet type with the highest median value sales appears to be the Type1 Supermarket.**

# %% [markdown]
# ### <font color='green'>Explanatory Visuals</font>

# %%
display(cln_df.head(), cln_df.columns)
# Out:
#   item_identifier  item_weight item_fat_content  item_visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                item_type  item_mrp outlet_identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    outlet_establishment_year    outlet_size outlet_location_type  \
# 0                       1999         Medium               Tier 1
# 1                       2009         Medium               Tier 3
# 2                       1999         Medium               Tier 1
# 3                       1998  missing value               Tier 3
# 4                       1987           High               Tier 3
#
#          outlet_type  item_outlet_sales
# 0  Supermarket Type1          3735.1380
# 1  Supermarket Type2           443.4228
# 2  Supermarket Type1          2097.2700
# 3      Grocery Store           732.3800
# 4  Supermarket Type1           994.7052
# Index(['item_identifier', 'item_weight', 'item_fat_content', 'item_visibility',
#        'item_type', 'item_mrp', 'outlet_identifier',
#        'outlet_establishment_year', 'outlet_size', 'outlet_location_type',
#        'outlet_type', 'item_outlet_sales'],
#       dtype='object')

# %% [markdown]
# #### What Types of Stores are We Looking at Here?

# %%
sns.set_style('whitegrid')
fig, g = plt.subplots(figsize=(5,3), dpi=250)
g = sns.countplot(data=cln_df, y='outlet_type')

g.set_title('What Types of Stores are in the Dataset?', pad=8)
g.set_xlabel('Number of Entries')
g.set_ylabel('Store Type')
g.set_xticks(range(0, 6000, 500))
g.set_xticklabels([i for i in g.get_xticks()], fontsize=6);

# %% [markdown]
# <u>Comment:</u> <br>
# <font color='dodgerblue'> <i>
# This Visualization is designed to show that "Supermarket Type1" is disproportionately respresented in the data.  So it is my opinion that any kind of analysis should take this into account, so we can make an apples to apples analysis of any underlying trends.  This is a data viz designed to set up the following datasets.
# </i></font>

# %% [markdown]
# #### How Many Individual Stores is This Analysis Based On?

# %%
sns.set_style('whitegrid')
fig, g2 = plt.subplots(figsize=(10,8), dpi=250)
g2 = sns.countplot(data=cln_df, y= 'outlet_identifier', hue='outlet_type')

g2.set_title('How Many Stores?  How Many Entries per Store?', pad=12)
g2.set_ylabel('Individual Stores')
g2.set_xlabel('Number of Entries')
g2.set_xticks(range(0,1100,100))
# g2.set_xticklabels([i for i in g.get_xticks()], fontsize=8);
g2.legend(loc=(1,.71));

# %% [markdown]
# <u>Comment:</u> <br>
# <font color='dodgerblue'> <i>
# This data viz further clarifies the last visualization, showing the type of each unique store, and the number of entries that come from that store.  It shows that there is only one of each "Supermarket Type2" and "Grocery Store" in the dataset.  In addition, the single grocery store in the dataset has around 60% of the number of entries that the rest of the stores contain.  In my opinion, any insight we can derive from this dataset should be reserved for "Supermarket Type1" stores.  The data suggest that the "Supermarket Type2" store is somewhat analogous to Type1 and could potentially be included, but would need to consult a subject matter expert.
# </i></font>

# %% [markdown]
# #### Which Store Is Our Top Performer for Total Sales?

# %%
# Filtering for only "Supermarket Type1"
supermarket1 = cln_df[cln_df['outlet_type'].str.contains('Supermarket Type1', case=False)].copy()
supermarket1.shape
# Out:
# (5577, 12)

# %%
supermarket1.groupby('outlet_identifier')['item_outlet_sales'].sum()
# Out:
# outlet_identifier
# OUT013    2.142664e+06
# OUT017    2.167465e+06
# OUT035    2.268123e+06
# OUT045    2.036725e+06
# OUT046    2.118395e+06
# OUT049    2.183970e+06
# Name: item_outlet_sales, dtype: float64

# %% [markdown]
# <u>Comment:</u> <br>
# <font color='dodgerblue'> <i>
# Here we can see which store is the top performer in terms of overall sales.
# </i></font>

# %%
from matplotlib.ticker import FuncFormatter

def hundred_k(x, pos):
  """function for use wth matplotlib FuncFormatter -  formats money in millions"""
  return f'${x*1e-6:,.1f}M'
price_fmt_100k = FuncFormatter(hundred_k)

fig, ax = plt.subplots(figsize=(4.5,3.5), dpi=350)
total_sales = supermarket1.groupby('outlet_identifier')['item_outlet_sales'].sum().reset_index()
ax = sns.barplot(data=total_sales, x='outlet_identifier', y='item_outlet_sales', 
    palette=['goldenrod' if i == 2 else 'cornflowerblue' for i in range(len(total_sales['outlet_identifier']))])

ax.set_title('Which Store Had the Highest Total Sales?', fontname='serif', pad=10)
ax.set_ylabel('Total Sales', fontname='serif', labelpad=6)
ax.set_xlabel('Supermarket Type1 Stores', fontname='serif', labelpad=6)

ax.set_yticks(range(0, 2400000, 100000))
ax.set_yticklabels(ax.get_yticks(), size=7)
ax.yaxis.set_major_formatter(price_fmt_100k)
ax.set_xticklabels([i for i in total_sales['outlet_identifier']], size=8)
ax.annotate('$2.27 M', xy=(1.6, 2110000), fontsize=8, fontname='serif');

# %% [markdown]
# <u>Comment:</u> <br>
# <font color='dodgerblue'> <i>
# This bar chart shows our top performing store in terms of overall sales ($2.27 Million).  It is not blowing the other stores out of the water, but my recommendation would be to see what factors are contributing to the increased sales.
# </i></font>

# %% [markdown]
# #### Which Specific Supermarket1 is the Top Performer for each Item Type?

# %%
# separating by item type for each supermarket1 type store, calculating the avg price for that item type
items_by_store = supermarket1.groupby(['outlet_identifier', 'item_type'])['item_outlet_sales'].mean().reset_index()

# getting the largest avg values
max_per_item = items_by_store.groupby('item_type')['item_outlet_sales'].max().reset_index()

# joining to include outlet id to show which items are top performers at which store.
best_performers = max_per_item.merge(items_by_store, on=['item_type', 'item_outlet_sales']).sort_values(['outlet_identifier', 'item_outlet_sales'])

# %%
fig, ax2 = plt.subplots(figsize=(6, 3), dpi=400)
ax2 = sns.barplot(data=best_performers, x='item_outlet_sales', y='item_type', hue='outlet_identifier', 
                  palette=['teal', 'yellowgreen', 'red', 'darkorange', 'dodgerblue'], dodge=False)
ax2.set_yticklabels([i for i in best_performers['item_type']], fontsize=7, fontname='serif');
ax2.set_xticks([i for i in range(0, 5000, 500)])
ax2.set_title('Which Stores are Top Performers in Each Item Category?', pad=12, fontname='serif', fontsize=18)
ax2.set_xlabel('Highest Average Sales (Supermarket Type1 Stores)', labelpad=6, fontname='serif')
ax2.set_ylabel('Item Category', labelpad=6, fontname='serif')
ax2.legend(title='Store ID', prop={'size':8});

# %% [markdown]
# <u>Comment:</u> <br>
# <font color='dodgerblue'> <i>
# This bar chart is showing which item categories have the highest average sales for each specific store.  In other words, which specific stores are best at selling which item categories.
# Observations:
# * Our top performer 035 does seem to validate it's highest overall sales.  It leads in starchy foods and breakfast food.
# * Store 046 is dominanting in seafood sales
#
# I would recommend looking more into why each store is performing well in each item category. Location? Demographics? Layout?
# It might also be worthwhile to see if increasing shelf space for better performing categories could tailor inventory to what shoppers are buying at that specific location.
# </i></font>
